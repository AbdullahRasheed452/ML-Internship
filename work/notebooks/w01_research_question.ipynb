# %% [markdown]
# <a href="https://colab.research.google.com/github/AbdullahRasheed452/ML-Internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# My lane: Lane 2, Refresh / Content Opportunity Scoring
# I'm picking this lane because it builds on what I already saw in Week 1.
# In Notebook 01, a hand written rule hit Precision@50 of about 0.24, while a trained model reached about 0.74.
# In Notebook 02, a readable decision tree kept its ranking advantage even on a held out test split.
# This lane lets me extend that same workflow into a ranked queue of pages for a content reviewer to check first, with clear reason codes instead of a black box score.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# Decision: which pages should a reviewer check first for refresh or content updates
# Who acts: a content reviewer with limited time each week
# Action: reviewer checks top ranked pages + reason codes, decides to update, leave, or rewrite
# Cost of false positive: wastes reviewer time on a page that wasn't a real problem
# Cost of false negative: a declining page goes unnoticed and keeps losing visibility
# Since time is limited, precision near the top of the list (P@20, P@50) matters most

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import os, subprocess

REPO_URL = "https://github.com/AbdullahRasheed452/ML-Internship"
REPO_DIR = "ML-Internship"

if not os.path.isdir(REPO_DIR):
    subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)
os.chdir(REPO_DIR)

# Load the starter dataset
import pandas as pd
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

# Number 1: how many pages are declining right now
declining_rate = (df["trend_direction"].str.lower() == "down").mean()
print(f"Declining rate: {declining_rate:.3f}")

# Number 2: how many pages are stale but still visible (candidates for this lane)
stale_visible = ((df["days_since_last_update"] >= 180) & (df["impressions_90d"] >= 500)).sum()
print(f"Stale but visible pages: {stale_visible}")

# Number 3: precision comparison from Week 1 (hand rule vs trained model)
print("Hand rule Precision@50: 0.24")
print("Random forest Precision@50: 0.74")
# Out:
# Declining rate: 0.542
# Stale but visible pages: 17
# Hand rule Precision@50: 0.24
# Random forest Precision@50: 0.74

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# What this work can say:
# -Observed: which pages show patterns like staleness, decline, or low CTR
# -Directional: whether a trained model ranks review candidates better than a hand rule
# -Decision support: a ranked list to help a reviewer prioritize limited time

# What this work cannot say:
# -It cannot prove a refresh will cause a page to recover, that needs a real experiment
# -It cannot claim to know Google's ranking algorithm
# -It cannot guarantee a flagged page is actually a problem, only that it fits a pattern

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
